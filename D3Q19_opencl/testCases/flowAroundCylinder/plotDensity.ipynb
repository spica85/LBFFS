# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# os.system('echo "rhoMax,rhoMin,rhoAve" > rho.dat')
# os.system('grep rhoMax log > tmp')
# os.system("awk '{print $2 $4 $6}' tmp >> rho.dat")

df = pd.read_csv('rho.dat')
#df.head()
df.plot()
# Out:
# <AxesSubplot:>
