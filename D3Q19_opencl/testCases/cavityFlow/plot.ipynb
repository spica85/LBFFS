# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

def plotU(df,cid=0,name=""):
    df.columns=['Points:1', 'u']

    cmap = plt.get_cmap('tab10')

    plt.plot(df['t'],df['y'],label=name+'Ave: %.2f'%(ave[0]),color=cmap(cid),linestyle='-')
    plt.plot(dfPart['t'],ave,color=cmap(cid),linestyle='--')


plt.figure(figsize=(6,6))
plt.rcParams["font.size"] = 16
plt.xlabel('$u$ (m/s)')
plt.ylabel('$y$ (m)')


df = pd.read_csv('u_x05.csv')
plt.plot(df['u'],df['Points:1'],label='LBM')

df = pd.read_csv('Ghia.dat')
plt.plot(df['u'],df['y'],label='Ghia', marker='o')

plt.legend()
plt.show()
